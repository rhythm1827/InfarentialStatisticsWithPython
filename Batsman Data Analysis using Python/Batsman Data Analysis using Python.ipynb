# %%
import pandas as pd
import numpy as np
import scipy as sp
import plotly.plotly as py
import plotly.figure_factory as ff
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import seaborn as sns
import scipy.stats
import scipy.stats as stats
import pylab as pl
import math

# %matplotlib inline


df = pd.read_csv("C:/Users/rhythm/Desktop/Downloads/dataset1_test.csv")
df.head(10)
# Out:
#    Batsman  Runs   Mins   BF  4s  6s      SR  Pos Dismissal  Inns
# 0        1    33   78.0   56   5   0   58.92    3    caught     2
# 1        1    33   77.0   49   6   0   67.34    3    caught     4
# 2        1   215  503.0  346  25   1   62.13    3       lbw     1
# 3        1    58   67.0   48   9   0  120.83    3    bowled     3
# 4        1     7   26.0   18   1   0   38.88    3    caught     1
# 5        1     8   40.0   27   1   0   29.62    3    caught     3
# 6        1     6    2.0    3   1   0  200.00    3    caught     1
# 7        1     5   20.0    9   1   0   55.55    3    caught     3
# 8        1   143  387.0  252  17   2   56.74    3    bowled     1
# 9        1    48   98.0   78   8   0   61.53    4    bowled     1

# %%
bt1 = df[(df.Batsman == 1)]
bt2 = df[(df.Batsman == 2)]
bt3 = df[(df.Batsman == 3)]
bt4 = df[(df.Batsman == 4)]
bt5 = df[(df.Batsman == 5)]
bt6 = df[(df.Batsman == 6)]

bti1_1 = df[(df.Batsman == 1)&(df.Inns == 1)]
bti2_1 = df[(df.Batsman == 2)&(df.Inns == 1)]
bti3_1 = df[(df.Batsman == 3)&(df.Inns == 1)]
bti4_1 = df[(df.Batsman == 4)&(df.Inns == 1)]
bti5_1 = df[(df.Batsman == 5)&(df.Inns == 1)]
bti6_1 = df[(df.Batsman == 6)&(df.Inns == 1)]

bti1_2 = df[(df.Batsman == 1)&(df.Inns == 2)]
bti2_2 = df[(df.Batsman == 2)&(df.Inns == 2)]
bti3_2 = df[(df.Batsman == 3)&(df.Inns == 2)]
bti4_2 = df[(df.Batsman == 4)&(df.Inns == 2)]
bti5_2 = df[(df.Batsman == 5)&(df.Inns == 2)]
bti6_2 = df[(df.Batsman == 6)&(df.Inns == 2)]

bti1_3 = df[(df.Batsman == 1)&(df.Inns == 3)]
bti2_3 = df[(df.Batsman == 2)&(df.Inns == 3)]
bti3_3 = df[(df.Batsman == 3)&(df.Inns == 3)]
bti4_3 = df[(df.Batsman == 4)&(df.Inns == 3)]
bti5_3 = df[(df.Batsman == 5)&(df.Inns == 3)]
bti6_3 = df[(df.Batsman == 6)&(df.Inns == 3)]

bti1_4 = df[(df.Batsman == 1)&(df.Inns == 4)]
bti2_4 = df[(df.Batsman == 2)&(df.Inns == 4)]
bti3_4 = df[(df.Batsman == 3)&(df.Inns == 4)]
bti4_4 = df[(df.Batsman == 4)&(df.Inns == 4)]
bti5_4 = df[(df.Batsman == 5)&(df.Inns == 4)]
bti6_4 = df[(df.Batsman == 6)&(df.Inns == 4)]


d = []
db1 = []
db2 = []
db3 = []
db4 = []
bt1.shape
p1 = len(bt1)
p2 = len(bt2)
p3 = len(bt3)
p4 = len(bt4)
p5 = len(bt5)
p6 = len(bt6)

played = []
played.append(p1)
played.append(p2)
played.append(p3)
played.append(p4)
played.append(p5)
played.append(p6)

print('Match Played by the players (1 to 6):',p1,' ',p2,' ',p3,' ',p4,' ',p5,' ',p6)
# Out:
# Match Played by the players (1 to 6): 57   52   64   59   38   26

# %%
print('===========================Batsman 1==============================')
print(bt1)
print('===========================Batsman 2==============================')
print(bt2)
print('===========================Batsman 3==============================')
print(bt3)
print('===========================Batsman 4==============================')
print(bt4)
print('===========================Batsman 5==============================')
print(bt5)
print('===========================Batsman 6==============================')
print(bt6)
# Out:
# ===========================Batsman 1==============================
#     Batsman  Runs   Mins   BF  4s  6s      SR  Pos Dismissal  Inns
# 0         1    33   78.0   56   5   0   58.92    3    caught     2
# 1         1    33   77.0   49   6   0   67.34    3    caught     4
# 2         1   215  503.0  346  25   1   62.13    3       lbw     1
# 3         1    58   67.0   48   9   0  120.83    3    bowled     3
# 4         1     7   26.0   18   1   0   38.88    3    caught     1
# 5         1     8   40.0   27   1   0   29.62    3    caught     3
# 6         1     6    2.0    3   1   0  200.00    3    caught     1
# 7         1     5   20.0    9   1   0   55.55    3    caught     3
# 8         1   143  387.0  252  17   2   56.74    3    bowled     1
# 9         1    48   98.0   78   8   0   61.53    4    bowled     1
# 10        1     1    8.0    2   0   0   50.00    4    caught     3
# 11        1    27   91.0   68   3   0   39.70    4    caught     1
# ...

# %%
average_runs_bt1 = np.mean(bt1['Runs'])
average_runs_bt1_inn1 = np.mean(bti1_1['Runs'])
average_runs_bt1_inn2 = np.mean(bti1_2['Runs'])
average_runs_bt1_inn3 = np.mean(bti1_3['Runs'])
average_runs_bt1_inn4 = np.mean(bti1_4['Runs'])


d.append(average_runs_bt1)
db1.append(average_runs_bt1_inn1)
db2.append(average_runs_bt1_inn2)
db3.append(average_runs_bt1_inn3)
db4.append(average_runs_bt1_inn4)

print('Average Runs of Player 1 is: ',average_runs_bt1)
print('Average Runs of Player 1(Innings 1) is: ',average_runs_bt1_inn1)
print('Average Runs of Player 1(Innings 2) is: ',average_runs_bt1_inn2)
print('Average Runs of Player 1(Innings 3) is: ',average_runs_bt1_inn3)
print('Average Runs of Player 1(Innings 4) is: ',average_runs_bt1_inn4)
# Out:
# Average Runs of Player 1 is:  60.87719298245614
# Average Runs of Player 1(Innings 1) is:  76.5
# Average Runs of Player 1(Innings 2) is:  75.625
# Average Runs of Player 1(Innings 3) is:  49.142857142857146
# Average Runs of Player 1(Innings 4) is:  31.636363636363637

# %%
average_runs_bt2 = np.mean(bt2['Runs'])
average_runs_bt2_inn1 = np.mean(bti2_1['Runs'])
average_runs_bt2_inn2 = np.mean(bti2_2['Runs'])
average_runs_bt2_inn3 = np.mean(bti2_3['Runs'])
average_runs_bt2_inn4 = np.mean(bti2_4['Runs'])

d.append(average_runs_bt2)
db1.append(average_runs_bt2_inn1)
db2.append(average_runs_bt2_inn2)
db3.append(average_runs_bt2_inn3)
db4.append(average_runs_bt2_inn4)

print('Average Runs of Player 2 is: ',average_runs_bt2)
print('Average Runs of Player 2(Innings 1) is: ',average_runs_bt2_inn1)
print('Average Runs of Player 2(Innings 2) is: ',average_runs_bt2_inn2)
print('Average Runs of Player 2(Innings 3) is: ',average_runs_bt2_inn3)
print('Average Runs of Player 2(Innings 4) is: ',average_runs_bt2_inn4)
# Out:
# Average Runs of Player 2 is:  57.55769230769231
# Average Runs of Player 2(Innings 1) is:  70.15789473684211
# Average Runs of Player 2(Innings 2) is:  79.63636363636364
# Average Runs of Player 2(Innings 3) is:  42.5
# Average Runs of Player 2(Innings 4) is:  17.333333333333332

# %%
average_runs_bt3 = np.mean(bt3['Runs'])
average_runs_bt3_inn1 = np.mean(bti3_1['Runs'])
average_runs_bt3_inn2 = np.mean(bti3_2['Runs'])
average_runs_bt3_inn3 = np.mean(bti3_3['Runs'])
average_runs_bt3_inn4 = np.mean(bti3_4['Runs'])

d.append(average_runs_bt3)
db1.append(average_runs_bt3_inn1)
db2.append(average_runs_bt3_inn2)
db3.append(average_runs_bt3_inn3)
db4.append(average_runs_bt3_inn4)

print('Average Runs of Player 3 is: ',average_runs_bt3)
print('Average Runs of Player 3(Innings 1) is: ',average_runs_bt3_inn1)
print('Average Runs of Player 3(Innings 2) is: ',average_runs_bt3_inn2)
print('Average Runs of Player 3(Innings 3) is: ',average_runs_bt3_inn3)
print('Average Runs of Player 3(Innings 4) is: ',average_runs_bt3_inn4)
# Out:
# Average Runs of Player 3 is:  49.078125
# Average Runs of Player 3(Innings 1) is:  65.72727272727273
# Average Runs of Player 3(Innings 2) is:  53.23076923076923
# Average Runs of Player 3(Innings 3) is:  40.7
# Average Runs of Player 3(Innings 4) is:  21.0

# %%
average_runs_bt4 = np.mean(bt4['Runs'])
average_runs_bt4_inn1 = np.mean(bti4_1['Runs'])
average_runs_bt4_inn2 = np.mean(bti4_2['Runs'])
average_runs_bt4_inn3 = np.mean(bti4_3['Runs'])
average_runs_bt4_inn4 = np.mean(bti4_4['Runs'])

d.append(average_runs_bt4)
db1.append(average_runs_bt4_inn1)
db2.append(average_runs_bt4_inn2)
db3.append(average_runs_bt4_inn3)
db4.append(average_runs_bt4_inn4)

print('Average Runs of Player 4 is: ',average_runs_bt4)
print('Average Runs of Player 4(Innings 1) is: ',average_runs_bt4_inn1)
print('Average Runs of Player 4(Innings 2) is: ',average_runs_bt4_inn2)
print('Average Runs of Player 4(Innings 3) is: ',average_runs_bt4_inn3)
print('Average Runs of Player 4(Innings 4) is: ',average_runs_bt4_inn4)
# Out:
# Average Runs of Player 4 is:  49.40677966101695
# Average Runs of Player 4(Innings 1) is:  64.8125
# Average Runs of Player 4(Innings 2) is:  42.94117647058823
# Average Runs of Player 4(Innings 3) is:  44.5
# Average Runs of Player 4(Innings 4) is:  43.75

# %%
average_runs_bt5 = np.mean(bt5['Runs'])
average_runs_bt5_inn1 = np.mean(bti5_1['Runs'])
average_runs_bt5_inn2 = np.mean(bti5_2['Runs'])
average_runs_bt5_inn3 = np.mean(bti5_3['Runs'])
average_runs_bt5_inn4 = np.mean(bti5_4['Runs'])

d.append(average_runs_bt5)
db1.append(average_runs_bt5_inn1)
db2.append(average_runs_bt5_inn2)
db3.append(average_runs_bt5_inn3)
db4.append(average_runs_bt5_inn4)

print('Average Runs of Player 5 is: ',average_runs_bt5)
print('Average Runs of Player 5(Innings 1) is: ',average_runs_bt5_inn1)
print('Average Runs of Player 5(Innings 2) is: ',average_runs_bt5_inn2)
print('Average Runs of Player 5(Innings 3) is: ',average_runs_bt5_inn3)
print('Average Runs of Player 5(Innings 4) is: ',average_runs_bt5_inn4)
# Out:
# Average Runs of Player 5 is:  53.026315789473685
# Average Runs of Player 5(Innings 1) is:  38.0
# Average Runs of Player 5(Innings 2) is:  66.14285714285714
# Average Runs of Player 5(Innings 3) is:  45.5
# Average Runs of Player 5(Innings 4) is:  52.625

# %%
average_runs_bt6 = np.mean(bt6['Runs'])
average_runs_bt6_inn1 = np.mean(bti6_1['Runs'])
average_runs_bt6_inn2 = np.mean(bti6_2['Runs'])
average_runs_bt6_inn3 = np.mean(bti6_3['Runs'])
average_runs_bt6_inn4 = np.mean(bti6_4['Runs'])

d.append(average_runs_bt6)
db1.append(average_runs_bt6_inn1)
db2.append(average_runs_bt6_inn2)
db3.append(average_runs_bt6_inn3)
db4.append(average_runs_bt6_inn4)

print('Average Runs of Player 6 is: ',average_runs_bt6)
print('Average Runs of Player 6(Innings 1) is: ',average_runs_bt6_inn1)
print('Average Runs of Player 6(Innings 2) is: ',average_runs_bt6_inn2)
print('Average Runs of Player 6(Innings 3) is: ',average_runs_bt6_inn3)
print('Average Runs of Player 6(Innings 4) is: ',average_runs_bt6_inn4)
# Out:
# Average Runs of Player 6 is:  35.76923076923077
# Average Runs of Player 6(Innings 1) is:  43.285714285714285
# Average Runs of Player 6(Innings 2) is:  44.0
# Average Runs of Player 6(Innings 3) is:  34.0
# Average Runs of Player 6(Innings 4) is:  19.166666666666668

# %%
sns.set()
x = np.arange(6)
_ = plt.bar(x, height= played)
_ = plt.xlabel('Player Name')
_ = plt.ylabel('Innings')
_ = plt.xticks(x, ['Smith','Kohli','Root','Warner','Williamson','Tamim'], color = 'blue')
_ = plt.title('Player Innings', color='brown')
plt.show()

# %%
x = np.arange(6)
_ = plt.bar(x, height= d)
_ = plt.xticks(x, ['Smith','Kohli','Root','Warner','Williamson','Tamim'], color = 'blue')
_ = plt.xlabel('Player Name')
_ = plt.ylabel('Average')
_ = plt.title('Average of the players', color = 'brown')
plt.show()

# %%
bt1 = df[(df.Batsman == 1)]
bt2 = df[(df.Batsman == 2)]
bt3 = df[(df.Batsman == 3)]
bt4 = df[(df.Batsman == 4)]
bt5 = df[(df.Batsman == 5)]
bt6 = df[(df.Batsman == 6)]


bti1_out = df[(df.Batsman == 1)&(df.Dismissal == 'not out')]
bti2_out = df[(df.Batsman == 2)&(df.Dismissal == 'not out')]
bti3_out = df[(df.Batsman == 3)&(df.Dismissal == 'not out')]
bti4_out = df[(df.Batsman == 4)&(df.Dismissal == 'not out')]
bti5_out = df[(df.Batsman == 5)&(df.Dismissal == 'not out')]
bti6_out = df[(df.Batsman == 6)&(df.Dismissal == 'not out')]

total_runs_bt1 = np.sum(bt1['Runs'])
total_runs_bt2 = np.sum(bt2['Runs'])
total_runs_bt3 = np.sum(bt3['Runs'])
total_runs_bt4 = np.sum(bt4['Runs'])
total_runs_bt5 = np.sum(bt5['Runs'])
total_runs_bt6 = np.sum(bt6['Runs'])


matchCountP1 = len(bt1) - len(bti1_out)
matchCountP2 = len(bt2) - len(bti2_out)
matchCountP3 = len(bt3) - len(bti3_out)
matchCountP4 = len(bt4) - len(bti4_out)
matchCountP5 = len(bt5) - len(bti5_out)
matchCountP6 = len(bt6) - len(bti6_out)

print(matchCountP1)
print(matchCountP2)
print(matchCountP3)
print(matchCountP4)
print(matchCountP5)
print(matchCountP6)
# Out:
# 49
# 48
# 60
# 57
# 33
# 26

# %%
avg_actual1 = total_runs_bt1 / matchCountP1
avg_actual2 = total_runs_bt2 / matchCountP2
avg_actual3 = total_runs_bt3 / matchCountP3
avg_actual4 = total_runs_bt4 / matchCountP4
avg_actual5 = total_runs_bt5 / matchCountP5
avg_actual6 = total_runs_bt6 / matchCountP6
print(avg_actual1)
print(avg_actual2)
print(avg_actual3)
print(avg_actual4)
print(avg_actual5)
print(avg_actual6)
# Out:
# 70.81632653061224
# 62.354166666666664
# 52.35
# 51.14035087719298
# 61.06060606060606
# 35.76923076923077

# %%
avg = []
avg.append(avg_actual1)
avg.append(avg_actual2)
avg.append(avg_actual3)
avg.append(avg_actual4)
avg.append(avg_actual5)
avg.append(avg_actual6)

x = np.arange(6)
_ = plt.bar(x, height= avg)
_ = plt.xticks(x, ['Smith','Kohli','Root','Warner','Williamson','Tamim'], color = 'blue')
_ = plt.xlabel('Player No')
_ = plt.ylabel('Average')
_ = plt.title('Average of the players')
plt.show()

# %%
x=np.arange(6)
bar_width=.30
plt.bar(x,avg,width=bar_width,color="green",zorder=2)
plt.bar(x+bar_width,d,width=bar_width,color="purple",zorder=2)

plt.xticks(x+.15, ['Smith','Kohli','Root','Warner','Williamson','Tamim'], color = 'blue')

plt.xlabel('Player Name')
plt.ylabel('Average')
plt.title('Normal mean average vs actual average', color='brown')

green_patch=mpatches.Patch(color="green",label="Actual Average")
red_patch=mpatches.Patch(color="purple",label="Average using mean")

plt.legend(handles=[green_patch,red_patch])

plt.grid(axis='y')
plt.show()

# %%
x1 = np.arange(6)
_ = plt.bar(x1, height= db1)
_ = plt.xticks(x1, ['Smith','Kohli','Root','Warner','Williamson','Tamim'], color = 'blue')
_ = plt.xlabel('Player No')
_ = plt.ylabel('Average')
_ = plt.title('Average of the players in first innings')
plt.show()

# %%
x2 = np.arange(6)
_ = plt.bar(x2, height= db2)
_ = plt.xticks(x2, ['Smith','Kohli','Root','Warner','Williamson','Tamim'], color = 'blue')
_ = plt.xlabel('Player No')
_ = plt.ylabel('Average')
_ = plt.title('Average of the players in second innings')
plt.show()

# %%
x3 = np.arange(6)
_ = plt.bar(x3, height= db3)
_ = plt.xticks(x3, ['Smith','Kohli','Root','Warner','Williamson','Tamim'], color = 'blue')
_ = plt.xlabel('Player No')
_ = plt.ylabel('Average')
_ = plt.title('Average of the players in third innings')
plt.show()

# %%
x4 = np.arange(6)
_ = plt.bar(x4, height= db4)
_ = plt.xticks(x1,['Smith','Kohli','Root','Warner','Williamson','Tamim'], color = 'blue')
_ = plt.xlabel('Player No')
_ = plt.ylabel('Average')
_ = plt.title('Average of the players in fourth innings')
plt.show()

# %%
pl1 = np.arange(p1)
_ = plt.bar(pl1, height = bt1['Runs'])
_ = plt.xlabel('Runs')
_ = plt.ylabel('Innings')
_ = plt.title('Steven Smith All Innings Score')
plt.show()

# %%
pl2 = np.arange(p2)
_ = plt.bar(pl2, height = bt2['Runs'])
_ = plt.xlabel('Runs')
_ = plt.ylabel('Innings')
_ = plt.title('Virat Kohli All Innings Score')
plt.show()

# %%
pl3 = np.arange(p3)
_ = plt.bar(pl3, height = bt3['Runs'])
_ = plt.xlabel('Runs')
_ = plt.ylabel('Innings')
_ = plt.title('Joe Root All Innings Score')
plt.show()

# %%
pl4 = np.arange(p4)
_ = plt.bar(pl4, height = bt4['Runs'])
_ = plt.xlabel('Runs')
_ = plt.ylabel('Innings')
_ = plt.title('David Warner All Innings Score')
plt.show()

# %%
pl5 = np.arange(p5)
_ = plt.bar(pl5, height = bt5['Runs'])
_ = plt.xlabel('Runs')
_ = plt.ylabel('Innings')
_ = plt.title('Kane Williamson All Innings Score')
plt.show()

# %%
pl6 = np.arange(p6)
_ = plt.bar(pl6, height = bt6['Runs'])
_ = plt.xlabel('Runs')
_ = plt.ylabel('Innings')
_ = plt.title('Tamim Iqbal All Innings Score')
plt.show()

# %%
total_runs_bt1= np.sum(bt1['Runs'])
print('Total Runs(Player 1): ',total_runs_bt1)
total_runs_bt2= np.sum(bt2['Runs'])
print('Total Runs(Player 2): ',total_runs_bt2)
total_runs_bt3= np.sum(bt3['Runs'])
print('Total Runs(Player 3): ',total_runs_bt3)
total_runs_bt4= np.sum(bt4['Runs'])
print('Total Runs(Player 4): ',total_runs_bt4)
total_runs_bt5= np.sum(bt5['Runs'])
print('Total Runs(Player 5): ',total_runs_bt5)
total_runs_bt6= np.sum(bt6['Runs'])
print('Total Runs(Player 6): ',total_runs_bt6)
# Out:
# Total Runs(Player 1):  3470
# Total Runs(Player 2):  2993
# Total Runs(Player 3):  3141
# Total Runs(Player 4):  2915
# Total Runs(Player 5):  2015
# Total Runs(Player 6):  930

# %%
total_4s_bt1= np.sum(bt1['4s'])
total_6s_bt1= np.sum(bt1['6s'])
total_runs_boundary_bt1 = total_4s_bt1*4 + total_6s_bt1*6
print('Player 1')
print('Runs Scored by 4s:', total_4s_bt1*4)
print('Runs Scored by 6s:', total_6s_bt1*6)
print('Runs Scored by boundary:', total_runs_boundary_bt1)
print('Runs Scored by boundary in %:', total_runs_boundary_bt1 / total_runs_bt1 * 100)
# Out:
# Player 1
# Runs Scored by 4s: 1528
# Runs Scored by 6s: 60
# Runs Scored by boundary: 1588
# Runs Scored by boundary in %: 45.763688760806915

# %%
total_4s_bt2= np.sum(bt2['4s'])
total_6s_bt2= np.sum(bt2['6s'])
total_runs_boundary_bt2 = total_4s_bt2*4 + total_6s_bt2*6
print('Player 2')
print('Runs Scored by 4s:', total_4s_bt2*4)
print('Runs Scored by 6s:', total_6s_bt2*6)
print('Runs Scored by boundary:', total_runs_boundary_bt2)
print('Runs Scored by boundary in %:', total_runs_boundary_bt2 / total_runs_bt2 * 100)
# Out:
# Player 2
# Runs Scored by 4s: 1260
# Runs Scored by 6s: 54
# Runs Scored by boundary: 1314
# Runs Scored by boundary in %: 43.90243902439025

# %%
total_4s_bt3= np.sum(bt3['4s'])
total_6s_bt3= np.sum(bt3['6s'])
total_runs_boundary_bt3 = total_4s_bt3*4 + total_6s_bt3*6
print('Player 3')
print('Runs Scored by 4s:', total_4s_bt3*4)
print('Runs Scored by 6s:', total_6s_bt3*6)
print('Runs Scored by boundary:', total_runs_boundary_bt3)
print('Runs Scored by boundary in %:', total_runs_boundary_bt3 / total_runs_bt3 * 100)
# Out:
# Player 3
# Runs Scored by 4s: 1552
# Runs Scored by 6s: 42
# Runs Scored by boundary: 1594
# Runs Scored by boundary in %: 50.748169372811205

# %%
total_4s_bt4= np.sum(bt4['4s'])
total_6s_bt4= np.sum(bt4['6s'])
total_runs_boundary_bt4 = total_4s_bt4*4 + total_6s_bt4*6
print('Player 4')
print('Runs Scored by 4s:', total_4s_bt4*4)
print('Runs Scored by 6s:', total_6s_bt4*6)
print('Runs Scored by boundary:', total_runs_boundary_bt4)
print('Runs Scored by boundary in %:', total_runs_boundary_bt4 / total_runs_bt4 * 100)
# Out:
# Player 4
# Runs Scored by 4s: 1392
# Runs Scored by 6s: 126
# Runs Scored by boundary: 1518
# Runs Scored by boundary in %: 52.075471698113205

# %%
total_4s_bt5= np.sum(bt5['4s'])
total_6s_bt5= np.sum(bt5['6s'])
total_runs_boundary_bt5 = total_4s_bt5*4 + total_6s_bt5*6
print('Player 5')
print('Runs Scored by 4s:', total_4s_bt5*4)
print('Runs Scored by 6s:', total_6s_bt5*6)
print('Runs Scored by boundary:', total_runs_boundary_bt5)
print('Runs Scored by boundary in %:', total_runs_boundary_bt5 / total_runs_bt5 * 100)
# Out:
# Player 5
# Runs Scored by 4s: 948
# Runs Scored by 6s: 36
# Runs Scored by boundary: 984
# Runs Scored by boundary in %: 48.83374689826302

# %%
total_4s_bt6= np.sum(bt6['4s'])
total_6s_bt6= np.sum(bt6['6s'])
total_runs_boundary_bt6 = total_4s_bt6*4 + total_6s_bt6*6
print('Player 6')
print('Runs Scored by 4s:', total_4s_bt6*4)
print('Runs Scored by 6s:', total_6s_bt6*6)
print('Runs Scored by boundary:', total_runs_boundary_bt6)
print('Runs Scored by boundary in %:', total_runs_boundary_bt6 / total_runs_bt6 * 100)
# Out:
# Player 6
# Runs Scored by 4s: 408
# Runs Scored by 6s: 36
# Runs Scored by boundary: 444
# Runs Scored by boundary in %: 47.74193548387097

# %%
t4s = []
t4s.append(total_4s_bt1)
t4s.append(total_4s_bt2)
t4s.append(total_4s_bt3)
t4s.append(total_4s_bt4)
t4s.append(total_4s_bt5)
t4s.append(total_4s_bt6)

x=np.arange(6)
bar_width=.50
plt.bar(x,t4s,width=bar_width,color="brown",zorder=2)

plt.xticks(x, ['Smith','Kohli','Root','Warner','Williamson','Tamim'], color = 'blue')

plt.xlabel('Player No')
plt.ylabel('No of 4s')
plt.title('Player scored 4s')

plt.grid(axis='y')
plt.show()

# %%
t6s = []
t6s.append(total_6s_bt1)
t6s.append(total_6s_bt2)
t6s.append(total_6s_bt3)
t6s.append(total_6s_bt4)
t6s.append(total_6s_bt5)
t6s.append(total_6s_bt6)
x=np.arange(6)
bar_width=.50
plt.bar(x,t6s,width=bar_width,color="blue",zorder=2)

plt.xticks(x, ['Smith','Kohli','Root','Warner','Williamson','Tamim'], color = 'blue')

plt.xlabel('Player No')
plt.ylabel('No of 6s')
plt.title('Player scored 6s')

plt.grid(axis='y')
plt.show()

# %%
x=np.arange(6)
bar_width=.30
plt.bar(x,t4s,width=bar_width,color="brown",zorder=2)
plt.bar(x+bar_width,t6s,width=bar_width,color="blue",zorder=2)

plt.xticks(x+bar_width*2-.40, ['Smith','Kohli','Root','Warner','Williamson','Tamim'])

plt.xlabel('Player Name')
plt.ylabel('No of boundaries')
plt.title('Player scored boundaries',color='green')

green_patch=mpatches.Patch(color="brown",label="4s")
red_patch=mpatches.Patch(color="blue",label="6s")

plt.legend(handles=[green_patch,red_patch])

plt.grid(axis='y')
plt.show()

# %%
runs_boundaryP1 = total_runs_boundary_bt1 / total_runs_bt1 * 100
runs_boundaryP2 = total_runs_boundary_bt2 / total_runs_bt2 * 100
runs_boundaryP3 = total_runs_boundary_bt3 / total_runs_bt3 * 100
runs_boundaryP4 = total_runs_boundary_bt4 / total_runs_bt4 * 100
runs_boundaryP5 = total_runs_boundary_bt5 / total_runs_bt5 * 100
runs_boundaryP6 = total_runs_boundary_bt6 / total_runs_bt6 * 100
boundaryRuns = []

boundaryRuns.append(runs_boundaryP1)
boundaryRuns.append(runs_boundaryP2)
boundaryRuns.append(runs_boundaryP3)
boundaryRuns.append(runs_boundaryP4)
boundaryRuns.append(runs_boundaryP5)
boundaryRuns.append(runs_boundaryP6)

# %%
x=np.arange(6)
bar_width=.50
plt.bar(x,boundaryRuns,width=bar_width,color="purple",zorder=2)
plt.xticks(x+bar_width*.5 - .25, ['Smith','Kohli','Root','Warner','Williamson','Tamim'])

plt.xlabel('Player Name')
plt.ylabel('Runs % in boundaries')
plt.title('Players score % only with boundary')

plt.grid(axis='y')
plt.show()

# %%
BF_P1 = np.sum(bt1['BF'])
BF_P2 = np.sum(bt2['BF'])
BF_P3 = np.sum(bt3['BF'])
BF_P4 = np.sum(bt4['BF'])
BF_P5 = np.sum(bt5['BF'])
BF_P6 = np.sum(bt6['BF'])
print('Balls Faced by Player 1: ',BF_P1)
print('Balls Faced by Player 2: ',BF_P2)
print('Balls Faced by Player 3: ',BF_P3)
print('Balls Faced by Player 4: ',BF_P4)
print('Balls Faced by Player 5: ',BF_P5)
print('Balls Faced by Player 6: ',BF_P6)
# Out:
# Balls Faced by Player 1:  6126
# Balls Faced by Player 2:  4712
# Balls Faced by Player 3:  5155
# Balls Faced by Player 4:  3880
# Balls Faced by Player 5:  3317
# Balls Faced by Player 6:  1694

# %%
STR_P1 = total_runs_bt1 * 100 / BF_P1
STR_P2 = total_runs_bt2 * 100 / BF_P2
STR_P3 = total_runs_bt3 * 100 / BF_P3
STR_P4 = total_runs_bt4 * 100 / BF_P4
STR_P5 = total_runs_bt5 * 100 / BF_P5
STR_P6 = total_runs_bt6 * 100 / BF_P6
print('Strike Rate by Player 1: ',STR_P1)
print('Strike Rate by Player 2: ',STR_P2)
print('Strike Rate by Player 3: ',STR_P3)
print('Strike Rate by Player 4: ',STR_P4)
print('Strike Rate by Player 5: ',STR_P5)
print('Strike Rate by Player 6: ',STR_P6)

avg_strike_rate_bt1= np.mean(bt1['SR'])
avg_strike_rate_bt2= np.mean(bt2['SR'])
avg_strike_rate_bt3= np.mean(bt3['SR'])
avg_strike_rate_bt4= np.mean(bt4['SR'])
avg_strike_rate_bt5= np.mean(bt5['SR'])
avg_strike_rate_bt6= np.mean(bt6['SR'])
print('Strike rate from strike rate column average Player 1',avg_strike_rate_bt1)
print('Strike rate from strike rate column average Player 2',avg_strike_rate_bt2)
print('Strike rate from strike rate column average Player 3',avg_strike_rate_bt3)
print('Strike rate from strike rate column average Player 4',avg_strike_rate_bt4)
print('Strike rate from strike rate column average Player 5',avg_strike_rate_bt5)
print('Strike rate from strike rate column average Player 6',avg_strike_rate_bt6)
# Out:
# Strike Rate by Player 1:  56.64381325497878
# Strike Rate by Player 2:  63.51867572156197
# Strike Rate by Player 3:  60.93113482056256
# Strike Rate by Player 4:  75.12886597938144
# Strike Rate by Player 5:  60.74766355140187
# Strike Rate by Player 6:  54.899645808736715
# Strike rate from strike rate column average Player 1 61.94947368421053
# Strike rate from strike rate column average Player 2 53.21596153846152
# Strike rate from strike rate column average Player 3 58.417656250000014
# Strike rate from strike rate column average Player 4 77.64610169491527
# Strike rate from strike rate column average Player 5 54.76578947368422
# Strike rate from strike rate column average Player 6 52.714999999999996

# %%
bs = []
bs.append(total_runs_boundary_bt1 / total_runs_bt1 * 100)
bs.append(total_runs_boundary_bt2 / total_runs_bt2 * 100)
bs.append(total_runs_boundary_bt3 / total_runs_bt3 * 100)
bs.append(total_runs_boundary_bt4 / total_runs_bt4 * 100)
bs.append(total_runs_boundary_bt5 / total_runs_bt5 * 100)
bs.append(total_runs_boundary_bt6 / total_runs_bt6 * 100)
bs_rate = np.arange(6)
_ = plt.bar(bs_rate, height= bs)
_ = plt.xticks(bs_rate,['Smith','Kohli','Root','Warner','Williamson','Tamim'], color = 'blue')
_ = plt.xlabel('Player No')
_ = plt.ylabel('Runs Scored(%)')
_ = plt.title('Runs Scored in boundaries(%)')
plt.show()

# %%
strr = []
strr.append(STR_P1)
strr.append(STR_P2)
strr.append(STR_P3)
strr.append(STR_P4)
strr.append(STR_P5)
strr.append(STR_P6)
st_rate = np.arange(6)
_ = plt.bar(st_rate, height= strr)
_ = plt.xticks(st_rate, ['Smith','Kohli','Root','Warner','Williamson','Tamim'], color = 'blue')
_ = plt.xlabel('Player No')
_ = plt.ylabel('Strike Rate')
_ = plt.title('Strike rate of the players')
plt.show()

# %%
strr = []
strr.append(avg_strike_rate_bt1)
strr.append(avg_strike_rate_bt2)
strr.append(avg_strike_rate_bt3)
strr.append(avg_strike_rate_bt4)
strr.append(avg_strike_rate_bt5)
strr.append(avg_strike_rate_bt6)
st_rate = np.arange(6)
_ = plt.bar(st_rate, height= strr, color = 'pink')
_ = plt.xticks(st_rate, ['Smith','Kohli','Root','Warner','Williamson','Tamim'])
_ = plt.xlabel('Player Name')
_ = plt.ylabel('Strike Rate')
_ = plt.title('Strike rate of the players', color='brown')
plt.show()

# %%
x=np.arange(6)
bar_width=.20
plt.bar(x,db1,width=bar_width,color="green",zorder=2)
plt.bar(x+bar_width,db2,width=bar_width,color="red",zorder=2)
plt.bar(x+bar_width*2,db3,width=bar_width,color="orange",zorder=2)
plt.bar(x+bar_width*3,db4,width=bar_width,color="purple",zorder=2)
plt.xticks(x+bar_width*2-.05, ['Smith','Kohli','Root','Warner','Williamson','Tamim'], color = 'blue')

plt.xlabel('Player Name')
plt.ylabel('Average')
plt.title('Average of the players in four innings', color='brown')

green_patch=mpatches.Patch(color="green",label="innings 1")
red_patch=mpatches.Patch(color="red",label="innings 2")
orange_patch=mpatches.Patch(color="orange",label="innings 3")
purple_patch=mpatches.Patch(color="purple",label="innings 4")

plt.legend(handles=[green_patch,red_patch,orange_patch,purple_patch])

plt.grid(axis='y')
plt.show()

# %%
avg_run_of_player_1=d[0]
avg_run_of_player_2=d[1]
avg_run_of_player_3=d[2]
avg_run_of_player_4=d[3]
avg_run_of_player_5=d[4]
avg_run_of_player_6=d[5]

exp_vals=[avg_run_of_player_1,avg_run_of_player_2,avg_run_of_player_3,avg_run_of_player_4,avg_run_of_player_5,avg_run_of_player_6]
colors = ['green', 'red', 'orange', 'purple','brown','grey']
green_patch=mpatches.Patch(color="green",label="Smith")
red_patch=mpatches.Patch(color="red",label="Kohli")
orange_patch=mpatches.Patch(color="orange",label="Root")
purple_patch=mpatches.Patch(color="purple",label="Warner")
brown_patch=mpatches.Patch(color="brown",label="Williamson")
grey_patch=mpatches.Patch(color="grey",label="Tamim")
plt.legend(handles=[green_patch,red_patch,orange_patch,purple_patch,brown_patch,grey_patch])

plt.axis("equal")
plt.title('% of runs if total runs is 100', color = 'blue')
plt.pie(exp_vals,colors=colors,radius=0.75,autopct='%0.3f%%',shadow=True)
plt.show()

# %%
exp_vals=[avg_strike_rate_bt1,avg_strike_rate_bt2,avg_strike_rate_bt3,avg_strike_rate_bt4,avg_strike_rate_bt5,avg_strike_rate_bt6]
exp_lebels=["Smith SR","Kohli SR","Root SR","Warner SR","Williamson SR","Tamim SR"]

colors = ['green', 'red', 'orange', 'purple','brown','grey']

plt.axis("equal")
plt.pie(exp_vals,labels=exp_lebels,colors=colors,radius=1.5,autopct='%0.1f%%',shadow=True)
plt.title('Batsman to bat when team need more rans with few balls remaining', color = 'blue')

plt.show()

# %%
Mins_P1 = np.sum(bt1['Mins'])
Mins_P2 = np.sum(bt2['Mins'])
Mins_P3 = np.sum(bt3['Mins'])
Mins_P4 = np.sum(bt4['Mins'])
Mins_P5 = np.sum(bt5['Mins'])
Mins_P6 = np.sum(bt6['Mins'])
print('Total Minutes stayed in the field by Player 1: ',Mins_P1)
print('Total Minutes stayed in the field by Player 2: ',Mins_P2)
print('Total Minutes stayed in the field by Player 3: ',Mins_P3)
print('Total Minutes stayed in the field by Player 4: ',Mins_P4)
print('Total Minutes stayed in the field by Player 5: ',Mins_P5)
print('Total Minutes stayed in the field by Player 6: ',Mins_P6)
# Out:
# Total Minutes stayed in the field by Player 1:  8859.0
# Total Minutes stayed in the field by Player 2:  6807.0
# Total Minutes stayed in the field by Player 3:  7514.0
# Total Minutes stayed in the field by Player 4:  5694.0
# Total Minutes stayed in the field by Player 5:  4982.0
# Total Minutes stayed in the field by Player 6:  2056.0

# %%
STTime_P1 = Mins_P1 / p1
STTime_P2 = Mins_P2 / p2
STTime_P3 = Mins_P3 / p3
STTime_P4 = Mins_P4 / p4
STTime_P5 = Mins_P5 / p5
STTime_P6 = Mins_P6 / p6
print('Average Stayed in the field per match by Player 1: ',STTime_P1)
print('Average Stayed in the field per match by Player 2: ',STTime_P2)
print('Average Stayed in the field per match by Player 3: ',STTime_P3)
print('Average Stayed in the field per match by Player 4: ',STTime_P4)
print('Average Stayed in the field per match by Player 5: ',STTime_P5)
print('Average Stayed in the field per match by Player 6: ',STTime_P6)
# Out:
# Average Stayed in the field per match by Player 1:  155.42105263157896
# Average Stayed in the field per match by Player 2:  130.90384615384616
# Average Stayed in the field per match by Player 3:  117.40625
# Average Stayed in the field per match by Player 4:  96.50847457627118
# Average Stayed in the field per match by Player 5:  131.10526315789474
# Average Stayed in the field per match by Player 6:  79.07692307692308

# %%
AvgMins = []
AvgMins.append(STTime_P1)
AvgMins.append(STTime_P2)
AvgMins.append(STTime_P3)
AvgMins.append(STTime_P4)
AvgMins.append(STTime_P5)
AvgMins.append(STTime_P6)
AvgMins_rate = np.arange(6)
_ = plt.bar(AvgMins_rate, height= AvgMins)
_ = plt.xticks(AvgMins_rate, ['Smith','Kohli','Root','Warner','Williamson','Tamim'], color = 'blue')
_ = plt.xlabel('Player Name')
_ = plt.ylabel('Average minutes stayed')
_ = plt.title('Players Stayed in the Ground per Innings')
plt.show()

# %%
bti1_1 = df[(df.Batsman == 1)&(df.Dismissal == 'run out')]
bti2_1 = df[(df.Batsman == 2)&(df.Dismissal == 'run out')]
bti3_1 = df[(df.Batsman == 3)&(df.Dismissal == 'run out')]
bti4_1 = df[(df.Batsman == 4)&(df.Dismissal == 'run out')]
bti5_1 = df[(df.Batsman == 5)&(df.Dismissal == 'run out')]
bti6_1 = df[(df.Batsman == 6)&(df.Dismissal == 'run out')]

bti1_2 = df[(df.Batsman == 1)&(df.Dismissal == 'not out')]
bti2_2 = df[(df.Batsman == 2)&(df.Dismissal == 'not out')]
bti3_2 = df[(df.Batsman == 3)&(df.Dismissal == 'not out')]
bti4_2 = df[(df.Batsman == 4)&(df.Dismissal == 'not out')]
bti5_2 = df[(df.Batsman == 5)&(df.Dismissal == 'not out')]
bti6_2 = df[(df.Batsman == 6)&(df.Dismissal == 'not out')]

bti1_3 = df[(df.Batsman == 1)&(df.Dismissal == 'stumped')]
bti2_3 = df[(df.Batsman == 2)&(df.Dismissal == 'stumped')]
bti3_3 = df[(df.Batsman == 3)&(df.Dismissal == 'stumped')]
bti4_3 = df[(df.Batsman == 4)&(df.Dismissal == 'stumped')]
bti5_3 = df[(df.Batsman == 5)&(df.Dismissal == 'stumped')]
bti6_3 = df[(df.Batsman == 6)&(df.Dismissal == 'stumped')]

bti1_4 = df[(df.Batsman == 1)&(df.Dismissal == 'lbw')]
bti2_4 = df[(df.Batsman == 2)&(df.Dismissal == 'lbw')]
bti3_4 = df[(df.Batsman == 3)&(df.Dismissal == 'lbw')]
bti4_4 = df[(df.Batsman == 4)&(df.Dismissal == 'lbw')]
bti5_4 = df[(df.Batsman == 5)&(df.Dismissal == 'lbw')]
bti6_4 = df[(df.Batsman == 6)&(df.Dismissal == 'lbw')]

bti1_5 = df[(df.Batsman == 1)&(df.Dismissal == 'bowled')]
bti2_5 = df[(df.Batsman == 2)&(df.Dismissal == 'bowled')]
bti3_5 = df[(df.Batsman == 3)&(df.Dismissal == 'bowled')]
bti4_5 = df[(df.Batsman == 4)&(df.Dismissal == 'bowled')]
bti5_5 = df[(df.Batsman == 5)&(df.Dismissal == 'bowled')]
bti6_5 = df[(df.Batsman == 6)&(df.Dismissal == 'bowled')]

bti1_6 = df[(df.Batsman == 1)&(df.Dismissal == 'caught')]
bti2_6 = df[(df.Batsman == 2)&(df.Dismissal == 'caught')]
bti3_6 = df[(df.Batsman == 3)&(df.Dismissal == 'caught')]
bti4_6 = df[(df.Batsman == 4)&(df.Dismissal == 'caught')]
bti5_6 = df[(df.Batsman == 5)&(df.Dismissal == 'caught')]
bti6_6 = df[(df.Batsman == 6)&(df.Dismissal == 'caught')]

d_out = []
db_out1 = []
db_out2 = []
db_out3 = []
db_out4 = []
db_out5 = []
db_out6 = []

db_out1.append(len(bti1_1))
db_out2.append(len(bti1_2))
db_out3.append(len(bti1_3))
db_out4.append(len(bti1_4))
db_out5.append(len(bti1_5))
db_out6.append(len(bti1_6))

db_out1.append(len(bti2_1))
db_out2.append(len(bti2_2))
db_out3.append(len(bti2_3))
db_out4.append(len(bti2_4))
db_out5.append(len(bti2_5))
db_out6.append(len(bti2_6))

db_out1.append(len(bti3_1))
db_out2.append(len(bti3_2))
db_out3.append(len(bti3_3))
db_out4.append(len(bti3_4))
db_out5.append(len(bti3_5))
db_out6.append(len(bti3_6))

db_out1.append(len(bti4_1))
db_out2.append(len(bti4_2))
db_out3.append(len(bti4_3))
db_out4.append(len(bti4_4))
db_out5.append(len(bti4_5))
db_out6.append(len(bti4_6))

db_out1.append(len(bti5_1))
db_out2.append(len(bti5_2))
db_out3.append(len(bti5_3))
db_out4.append(len(bti5_4))
db_out5.append(len(bti5_5))
db_out6.append(len(bti5_6))

db_out1.append(len(bti6_1))
db_out2.append(len(bti6_2))
db_out3.append(len(bti6_3))
db_out4.append(len(bti6_4))
db_out5.append(len(bti6_5))
db_out6.append(len(bti6_6))

print('=====================================')

print('Player 1 run out',len(bti1_1))
print('Player 1 not out',len(bti1_2))
print('Player 1 stumped out',len(bti1_3))
print('Player 1 lbw out',len(bti1_4))
print('Player 1 bowled out',len(bti1_5))
print('Player 1 caught out',len(bti1_6))
print('=====================================')

print('Player 2 run out',len(bti2_1))
print('Player 2 not out',len(bti2_2))
print('Player 2 stumped out',len(bti2_3))
print('Player 2 lbw out',len(bti2_4))
print('Player 2 bowled out',len(bti2_5))
print('Player 2 caught out',len(bti2_6))
print('=====================================')

print('Player 3 run out',len(bti3_1))
print('Player 3 not out',len(bti3_2))
print('Player 3 stumped out',len(bti3_3))
print('Player 3 lbw out',len(bti3_4))
print('Player 3 bowled out',len(bti3_5))
print('Player 3 caught out',len(bti3_6))
print('=====================================')

print('Player 4 run out',len(bti4_1))
print('Player 4 not out',len(bti4_2))
print('Player 4 stumped out',len(bti4_3))
print('Player 4 lbw out',len(bti4_4))
print('Player 4 bowled out',len(bti4_5))
print('Player 4 caught out',len(bti4_6))
print('=====================================')

print('Player 5 run out',len(bti5_1))
print('Player 5 not out',len(bti5_2))
print('Player 5 stumped out',len(bti5_3))
print('Player 5 lbw out',len(bti5_4))
print('Player 5 bowled out',len(bti5_5))
print('Player 5 caught out',len(bti5_6))
print('=====================================')

print('Player 6 run out',len(bti6_1))
print('Player 6 not out',len(bti6_2))
print('Player 6 stumped out',len(bti6_3))
print('Player 6 lbw out',len(bti6_4))
print('Player 6 bowled out',len(bti6_5))
print('Player 6 caught out',len(bti6_6))
print('=====================================')
# Out:
# ...
# Player 1 run out 1
# Player 1 not out 8
# Player 1 stumped out 2
# Player 1 lbw out 8
# Player 1 bowled out 11
# Player 1 caught out 27
# ...
# Player 2 run out 0
# Player 2 not out 4
# Player 2 stumped out 0
# Player 2 lbw out 14
# Player 2 bowled out 3
# Player 2 caught out 30
# ...
# Player 3 run out 0
# Player 3 not out 4
# Player 3 stumped out 0
# Player 3 lbw out 13
# Player 3 bowled out 8
# Player 3 caught out 39
# ...
# Player 4 run out 2
# Player 4 not out 2
# Player 4 stumped out 0
# Player 4 lbw out 8
# Player 4 bowled out 8
# Player 4 caught out 39
# ...
# Player 5 run out 0
# Player 5 not out 5
# Player 5 stumped out 0
# Player 5 lbw out 5
# Player 5 bowled out 5
# Player 5 caught out 23
# ...
# Player 6 run out 2
# Player 6 not out 0
# Player 6 stumped out 1
# Player 6 lbw out 5
# Player 6 bowled out 4
# Player 6 caught out 14
# ...

# %%
x=np.arange(6)
bar_width=.16
plt.bar(x,db_out1,width=bar_width,color="green",zorder=2)
plt.bar(x+bar_width,db_out2,width=bar_width,color="red",zorder=2)
plt.bar(x+bar_width*2,db_out3,width=bar_width,color="orange",zorder=2)
plt.bar(x+bar_width*3,db_out4,width=bar_width,color="purple",zorder=2)
plt.bar(x+bar_width*4,db_out5,width=bar_width,color="brown",zorder=2)
plt.bar(x+bar_width*5,db_out6,width=bar_width,color="grey",zorder=2)
plt.xticks(x+bar_width*6-.50, ['Smith','Kohli','Root','Warner','Williamson','Tamim'])

plt.xlabel('Player Name')
plt.ylabel('No of times outs')
plt.title('Out Categories of the players')

green_patch=mpatches.Patch(color="green",label="run out")
red_patch=mpatches.Patch(color="red",label="not out")
orange_patch=mpatches.Patch(color="orange",label="stumped")
purple_patch=mpatches.Patch(color="purple",label="lbw")
brown_patch=mpatches.Patch(color="brown",label="bowled")
grey_patch=mpatches.Patch(color="grey",label="caught")
plt.legend(handles=[green_patch,red_patch,orange_patch,purple_patch,brown_patch,grey_patch])

plt.grid(axis='y')
plt.show()

# %%
_ = plt.plot(bt1['Runs'], bt1['BF'], marker = '.', linestyle = 'none')
_ = plt.margins(0.02)
_ = plt.xlabel ('Runs')
_ = plt.ylabel ('Balls Faced')
_ = plt.title('Smith Runs vs Balls Graph')
plt.show()

# %%
_ = plt.plot(bt2['Runs'], bt2['BF'], marker = '.', linestyle = 'none')
_ = plt.margins(0.02)
_ = plt.xlabel ('Runs')
_ = plt.ylabel ('Balls Faced')
_ = plt.title('Kohli Runs vs Balls Graph')
plt.show()

# %%
_ = plt.plot(bt3['Runs'], bt3['BF'], marker = '.', linestyle = 'none')
_ = plt.margins(0.02)
_ = plt.xlabel ('Runs')
_ = plt.ylabel ('Balls Faced')
_ = plt.title('Root Runs vs Balls Graph')
plt.show()

# %%
_ = plt.plot(bt4['Runs'], bt4['BF'], marker = '.', linestyle = 'none')
_ = plt.margins(0.02)
_ = plt.xlabel ('Runs')
_ = plt.ylabel ('Balls Faced')
_ = plt.title('Warner Runs vs Balls Graph')
plt.show()

# %%
_ = plt.plot(bt5['Runs'], bt5['BF'], marker = '.', linestyle = 'none')
_ = plt.margins(0.02)
_ = plt.xlabel ('Runs')
_ = plt.ylabel ('Balls Faced')
_ = plt.title('Willamson Runs vs Balls Graph')
plt.show()

# %%
_ = plt.plot(bt6['Runs'], bt6['BF'], marker = '.', linestyle = 'none')
_ = plt.margins(0.02)
_ = plt.xlabel ('Runs')
_ = plt.ylabel ('Balls Faced')
_ = plt.title('Tamim Runs vs Balls Graph')
plt.show()

# %%
confidence = 0.90
a = bt1.Runs
n = p1
m, se = np.mean(a), scipy.stats.sem(a)
h = se * sp.stats.t.ppf(confidence, n-1)

σ = np.std(a)
z = stats.norm.ppf(confidence)
dis = z*σ/math.sqrt(n)
print ('==========Smith average runs t Distribution==========','\nMean: ', "%.2f" % m,' Range: ', "%.2f" % (m-h) ,' to ', "%.2f" % (m+h))
print ('========Smith average runs Normal Distribution=======','\nMean: ', "%.2f" % m,' Range: ', "%.2f" % (m-dis),' to ', "%.2f" % (m+dis))
# Out:
# ==========Smith average runs t Distribution==========
# Mean:  60.88  Range:  51.09  to  70.66
# ========Smith average runs Normal Distribution=======
# Mean:  60.88  Range:  51.29  to  70.46

# %%
confidence = 0.90
a = bt2.Runs
n = p2
m, se = np.mean(a), scipy.stats.sem(a)
h = se * sp.stats.t.ppf(confidence, n-1)

σ = np.std(a)
z = stats.norm.ppf(confidence)
dis = z*σ/math.sqrt(n)
print ('==========Kohli average runs t Distribution==========','\nMean: ', "%.2f" % m,' Range: ', "%.2f" % (m-h) ,' to ', "%.2f" % (m+h))
print ('========Kohli average runs Normal Distribution=======','\nMean: ', "%.2f" % m,' Range: ', "%.2f" % (m-dis),' to ', "%.2f" % (m+dis))
# Out:
# ==========Kohli average runs t Distribution==========
# Mean:  57.56  Range:  45.04  to  70.07
# ========Kohli average runs Normal Distribution=======
# Mean:  57.56  Range:  45.32  to  69.79

# %%
confidence = 0.90
a = bt3.Runs
n = p3
m, se = np.mean(a), scipy.stats.sem(a)
h = se * sp.stats.t.ppf(confidence, n-1)

σ = np.std(a)
z = stats.norm.ppf(confidence)
dis = z*σ/math.sqrt(n)
print ('==========Root average runs t Distribution==========','\nMean: ', "%.2f" % m,' Range: ', "%.2f" % (m-h) ,' to ', "%.2f" % (m+h))
print ('========Root average runs Normal Distribution=======','\nMean: ', "%.2f" % m,' Range: ', "%.2f" % (m-dis),' to ', "%.2f" % (m+dis))
# Out:
# ==========Root average runs t Distribution==========
# Mean:  49.08  Range:  41.29  to  56.87
# ========Root average runs Normal Distribution=======
# Mean:  49.08  Range:  41.43  to  56.73

# %%
confidence = 0.90
a = bt4.Runs
n = p4
m, se = np.mean(a), scipy.stats.sem(a)
h = se * sp.stats.t.ppf(confidence, n-1)

σ = np.std(a)
z = stats.norm.ppf(confidence)
dis = z*σ/math.sqrt(n)
print ('==========Warner average runs t Distribution==========','\nMean: ', "%.2f" % m,' Range: ', "%.2f" % (m-h) ,' to ', "%.2f" % (m+h))
print ('========Warner average runs Normal Distribution=======','\nMean: ', "%.2f" % m,' Range: ', "%.2f" % (m-dis),' to ', "%.2f" % (m+dis))
# Out:
# ==========Warner average runs t Distribution==========
# Mean:  49.41  Range:  41.16  to  57.65
# ========Warner average runs Normal Distribution=======
# Mean:  49.41  Range:  41.32  to  57.49

# %%
confidence = 0.90
a = bt5.Runs
n = p5
m, se = np.mean(a), scipy.stats.sem(a)
h = se * sp.stats.t.ppf(confidence, n-1)

σ = np.std(a)
z = stats.norm.ppf(confidence)
dis = z*σ/math.sqrt(n)
print ('==========Williamson average runs t Distribution==========','\nMean: ', "%.2f" % m,' Range: ', "%.2f" % (m-h) ,' to ', "%.2f" % (m+h))
print ('========Williamson average runs Normal Distribution=======','\nMean: ', "%.2f" % m,' Range: ', "%.2f" % (m-dis),' to ', "%.2f" % (m+dis))
# Out:
# ==========Williamson average runs t Distribution==========
# Mean:  53.03  Range:  42.55  to  63.50
# ========Williamson average runs Normal Distribution=======
# Mean:  53.03  Range:  42.87  to  63.18

# %%
confidence = 0.90
a = bt6.Runs
n = p6
m, se = np.mean(a), scipy.stats.sem(a)
h = se * sp.stats.t.ppf(confidence, n-1)

σ = np.std(a)
z = stats.norm.ppf(confidence)
dis = z*σ/math.sqrt(n)
print ('==========Tamim average runs t Distribution==========','\nMean: ', "%.2f" % m,' Range: ', "%.2f" % (m-h) ,' to ', "%.2f" % (m+h))
print ('========Tamim average runs Normal Distribution=======','\nMean: ', "%.2f" % m,' Range: ', "%.2f" % (m-dis),' to ', "%.2f" % (m+dis))
# Out:
# ==========Tamim average runs t Distribution==========
# Mean:  35.77  Range:  27.93  to  43.61
# ========Tamim average runs Normal Distribution=======
# Mean:  35.77  Range:  28.29  to  43.25

# %%
x1 = bt1['Runs']
y1 = x1 + bt1['Mins']
pearson_coefficient_P1 = np.corrcoef(x1,y1)
print (pearson_coefficient_P1)
print ("Steven Smith Pearson correleation coefficient between runs and mins = ", pearson_coefficient_P1 [0][1])
matplotlib.style.use('ggplot')
plt.xlabel('Runs')
plt.ylabel('Mins')
plt.title('Steven Smith Pearson correleation coefficient between runs and mins')
plt.scatter(x1,y1)
plt.show()
# Out:
# [[ 1.          0.96965182]
#  [ 0.96965182  1.        ]]
# Steven Smith Pearson correleation coefficient between runs and mins =  0.969651823506

# %%
x1 = bt2['Runs']
y1 = x1 + bt2['Mins']
pearson_coefficient_P1 = np.corrcoef(x1,y1)
print (pearson_coefficient_P1)
print ("Virat Kohli Pearson correleation coefficient between runs and mins = ", pearson_coefficient_P1 [0][1])
matplotlib.style.use('ggplot')
plt.xlabel('Runs')
plt.ylabel('Mins')
plt.title('Virat Kohli Pearson correleation coefficient between runs and mins')
plt.scatter(x1,y1)
plt.show()
# Out:
# [[ 1.          0.98494739]
#  [ 0.98494739  1.        ]]
# Virat Kohli Pearson correleation coefficient between runs and mins =  0.984947389911

# %%
x1 = bt3['Runs']
y1 = x1 + bt3['Mins']
pearson_coefficient_P1 = np.corrcoef(x1,y1)
print (pearson_coefficient_P1)
print ("Joe Root Pearson correleation coefficient between runs and mins = ", pearson_coefficient_P1 [0][1])
matplotlib.style.use('ggplot')
plt.xlabel('Runs')
plt.ylabel('Mins')
plt.title('Joe Root Pearson correleation coefficient between runs and mins')
plt.scatter(x1,y1)
plt.show()
# Out:
# [[ 1.          0.97615407]
#  [ 0.97615407  1.        ]]
# Joe Root Pearson correleation coefficient between runs and mins =  0.976154069449

# %%
x1 = bt4['Runs']
y1 = x1 + bt4['Mins']
pearson_coefficient_P1 = np.corrcoef(x1,y1)
print (pearson_coefficient_P1)
print ("David Warner Pearson correleation coefficient between runs and mins = ", pearson_coefficient_P1 [0][1])
matplotlib.style.use('ggplot')
plt.xlabel('Runs')
plt.ylabel('Mins')
plt.title('David Warner Pearson correleation coefficient between runs and mins')
plt.scatter(x1,y1)
plt.show()
# Out:
# [[ 1.          0.96116593]
#  [ 0.96116593  1.        ]]
# David Warner Pearson correleation coefficient between runs and mins =  0.961165930603

# %%
x1 = bt5['Runs']
y1 = x1 + bt5['Mins']
pearson_coefficient_P1 = np.corrcoef(x1,y1)
print (pearson_coefficient_P1)
print ("Kane Williamson Pearson correleation coefficient between runs and mins = ", pearson_coefficient_P1 [0][1])
matplotlib.style.use('ggplot')
plt.xlabel('Runs')
plt.ylabel('Mins')
plt.title('Kane Williamson Pearson correleation coefficient between runs and mins')
plt.scatter(x1,y1)
plt.show()
# Out:
# [[ 1.          0.96679807]
#  [ 0.96679807  1.        ]]
# Kane Williamson Pearson correleation coefficient between runs and mins =  0.966798066549

# %%
x1 = bt6['Runs']
y1 = x1 + bt6['Mins']
pearson_coefficient_P1 = np.corrcoef(x1,y1)
print (pearson_coefficient_P1)
print ("Tamim Iqbal Pearson correleation coefficient between runs and mins = ", pearson_coefficient_P1 [0][1])
matplotlib.style.use('ggplot')
plt.xlabel('Runs')
plt.ylabel('Mins')
plt.title('Tamim Iqbal Pearson correleation coefficient between runs and mins')
plt.scatter(x1,y1)
plt.show()
# Out:
# [[  1.  nan]
#  [ nan  nan]]
# Tamim Iqbal Pearson correleation coefficient between runs and mins =  nan

# %%
btP1 = df[(df.Batsman == 1)]
btP2 = df[(df.Batsman == 2)]
btP3 = df[(df.Batsman == 3)]
btP4 = df[(df.Batsman == 4)]
btP5 = df[(df.Batsman == 5)]
btP6 = df[(df.Batsman == 6)]

av1 = btP1['BF']
av2 = btP2['BF']
av3 = btP3['BF']
av4 = btP4['BF']
av5 = btP5['BF']
av6 = btP6['BF']

av = []
av.append(np.sum(av1)/p1)
av.append(np.sum(av2)/p2)
av.append(np.sum(av3)/p3)
av.append(np.sum(av4)/p4)
av.append(np.sum(av5)/p5)
av.append(np.sum(av6)/p6)

AvgBF_rate = np.arange(6)
_ = plt.bar(AvgBF_rate, height= av, color = 'green')
_ = plt.xticks(AvgBF_rate, ['Smith','Kohli','Root','Warner','Williamson','Tamim'], color = 'blue')
_ = plt.xlabel('Player Name')
_ = plt.ylabel('Balls faced')
_ = plt.title('Players Balls faced per Innings')
plt.show()

# %%
sns.set()
_ = sns.swarmplot(x= 'Batsman', y = 'Runs', data = df)
_ = plt.margins(0.05)
_ = plt.xlabel ('Batsman')
_ = plt.ylabel ('Runs')
_ = plt.title('Batsman Runs Swarmplot', color = 'brown')
_ = plt.xticks(AvgBF_rate, ['Smith','Kohli','Root','Warner','Williamson','Tamim'], color = 'blue')
plt.show()

# %%
sns.set()
_ = sns.boxplot(x= 'Batsman', y = 'Runs', data = df)
_ = plt.margins(0.05)
_ = plt.xlabel ('Batsman')
_ = plt.ylabel ('Runs')
_ = plt.title('Batsman Runs Boxplot', color = 'brown')
_ = plt.xticks(AvgBF_rate, ['Smith','Kohli','Root','Warner','Williamson','Tamim'], color = 'blue')
plt.show()

# %%
sns.set()
_ = plt.plot(df['Batsman'], df['Runs'], marker = '.', linestyle = 'none')
_ = plt.margins(0.05)
_ = plt.xlabel ('Batsman')
_ = plt.ylabel ('Runs')
_ = plt.title('Batsman Runs plot', color = 'brown')
_ = plt.xticks(AvgBF_rate, ['Smith','Kohli','Root','Warner','Williamson','Tamim'], color = 'blue')
plt.show()

# %%
sns.set()
_ = sns.swarmplot(x= 'Batsman', y = 'BF', data = df)
_ = plt.margins(0.05)
_ = plt.xlabel ('Batsman')
_ = plt.ylabel ('Balls')
_ = plt.title('Batsman Balls Swarmplot', color = 'brown')
_ = plt.xticks(AvgBF_rate, ['Smith','Kohli','Root','Warner','Williamson','Tamim'], color = 'blue')
plt.show()

# %%
sns.set()
_ = sns.boxplot(x= 'Batsman', y = 'BF', data = df)
_ = plt.margins(0.05)
_ = plt.xlabel ('Batsman')
_ = plt.ylabel ('Balls')
_ = plt.title('Batsman Balls Boxplot', color = 'brown')
_ = plt.xticks(AvgBF_rate, ['Smith','Kohli','Root','Warner','Williamson','Tamim'], color = 'blue')
plt.show()

# %%
sns.set()
_ = plt.plot(df['Batsman'], df['BF'], marker = '.', linestyle = 'none')
_ = plt.margins(0.05)
_ = plt.xlabel ('Batsman')
_ = plt.ylabel ('Balls')
_ = plt.title('Batsman Balls plot', color = 'brown')
_ = plt.xticks(AvgBF_rate, ['Smith','Kohli','Root','Warner','Williamson','Tamim'], color = 'blue')
plt.show()

# %%
h = sorted(bt1.Runs)
fit = stats.norm.pdf(h, np.mean(h), np.std(h))
pl.plot(h,fit,'-o')
pl.hist(h,normed=True)
pl.title('Steven Smith runs in normal distribution')
pl.show()

# %%
h = sorted(bt2.Runs)
fit = stats.norm.pdf(h, np.mean(h), np.std(h))
pl.plot(h,fit,'-o')
pl.hist(h,normed=True)
pl.title('Virat Kohli runs in normal distribution')
pl.show()

# %%
h = sorted(bt3.Runs)
fit = stats.norm.pdf(h, np.mean(h), np.std(h))
pl.plot(h,fit,'-o')
pl.hist(h,normed=True)
pl.title('Joe Root runs in normal distribution')
pl.show()

# %%
h = sorted(bt4.Runs)
fit = stats.norm.pdf(h, np.mean(h), np.std(h))
pl.plot(h,fit,'-o')
pl.hist(h,normed=True)
pl.title('David Warner runs in normal distribution')
pl.show()

# %%
h = sorted(bt5.Runs)
fit = stats.norm.pdf(h, np.mean(h), np.std(h))
pl.plot(h,fit,'-o')
pl.hist(h,normed=True)
pl.title('Kane Williamson runs in normal distribution')
pl.show()

# %%
h = sorted(bt6.Runs)
fit = stats.norm.pdf(h, np.mean(h), np.std(h))
pl.plot(h,fit,'-o')
pl.hist(h,normed=True)
pl.title('Tamim Iqbal runs in normal distribution')
pl.show()

# %%
h = sorted(bt1.Runs)
hmean = np.mean(h)
hstd = np.std(h)
pdf = stats.norm.pdf(h, hmean, hstd)
plt.title('Steven Smith runs in normal distribution')
plt.plot(h, pdf)

# %%
h = sorted(bt2.Runs)
hmean = np.mean(h)
hstd = np.std(h)
pdf = stats.norm.pdf(h, hmean, hstd)
plt.title('Virat Kohli runs in normal distribution')
plt.plot(h, pdf)

# %%
h = sorted(bt3.Runs)
hmean = np.mean(h)
hstd = np.std(h)
pdf = stats.norm.pdf(h, hmean, hstd)
plt.title('Joe Root runs in normal distribution')
plt.plot(h, pdf)

# %%
h = sorted(bt4.Runs)
hmean = np.mean(h)
hstd = np.std(h)
pdf = stats.norm.pdf(h, hmean, hstd)
plt.title('David Warner runs in normal distribution')
plt.plot(h, pdf)

# %%
h = sorted(bt5.Runs)
hmean = np.mean(h)
hstd = np.std(h)
pdf = stats.norm.pdf(h, hmean, hstd)
plt.title('Kane Williamson runs in normal distribution')
plt.plot(h, pdf)

# %%
h = sorted(bt6.Runs)
hmean = np.mean(h)
hstd = np.std(h)
pdf = stats.norm.pdf(h, hmean, hstd)
plt.title('Tamim Iqbal runs in normal distribution')
plt.plot(h, pdf)
